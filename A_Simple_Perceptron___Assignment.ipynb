# %% [markdown]
# Question 1: What is Deep Learning? Briefly describe how it evolved and how it differs
# from traditional machine learning

# %% [markdown]
# => In Machine Learning, for image recognition, you manually extract edges, shapes, or textures.
#
# In Deep Learning, the model automatically learns these patterns layer by layer — from edges → shapes → objects.

# %% [markdown]
# Question 2: Explain the basic architecture and functioning of a Perceptron. What are its
# limitations?

# %% [markdown]
# => A Perceptron is the building block of neural networks.
#
# It learns a linear decision boundary to separate two classes.
#
# Its limitations led to the development of Multi-Layer Perceptrons (MLP), which can solve non-linear problems.

# %% [markdown]
# Question 3: Describe the purpose of activation function in neural networks. Compare
# Sigmoid, ReLU, and Tanh functions.

# %% [markdown]
# => Activation functions help the network learn non-linear decision boundaries.
#
# Sigmoid and Tanh are useful for small or probability-based outputs.
#
# ReLU is the most popular in modern deep learning due to its simplicity and efficiency.

# %% [markdown]
# Question 4: What is the difference between Loss function and Cost function in neural
# networks? Provide examples.

# %% [markdown]
# * Loss Function: Error for one example
# * Cost Function: Average loss for all examples in the dataset

# %% [markdown]
# Question 5: What is the role of optimizers in neural networks? Compare Gradient
# Descent, Adam, and RMSprop.

# %% [markdown]
# => Optimizers help the network learn efficiently by updating weights in the right direction and magnitude.
#
# Among them, Adam is the most popular in deep learning due to its adaptive learning rate and momentum combination.

# %% [markdown]
# Question 6: Write a Python program to implement a single-layer perceptron from
# scratch using NumPy to solve the logical AND gate.

# %%
import numpy as np

X = np.array([[0,0],
              [0,1],
              [1,0],
              [1,1]])

y = np.array([0, 0, 0, 1])

weights = np.random.rand(2)
bias = np.random.rand(1)
learning_rate = 0.1

def step_function(x):
    return np.where(x >= 0, 1, 0)

for epoch in range(20):
    for i in range(len(X)):
        z = np.dot(X[i], weights) + bias
        y_pred = step_function(z)
        error = y[i] - y_pred
        weights += learning_rate * error * X[i]
        bias += learning_rate * error

print("Final weights:", weights)
print("Final bias:", bias)

print("\nTesting AND Gate:")
for i in range(len(X)):
    z = np.dot(X[i], weights) + bias
    y_pred = step_function(z)
    print(f"Input: {X[i]} → Predicted Output: {y_pred[0]}")
# Out:
# Final weights: [0.20832188 0.10158203]
# Final bias: [-0.21991432]
#
# Testing AND Gate:
# Input: [0 0] → Predicted Output: 0
# Input: [0 1] → Predicted Output: 0
# Input: [1 0] → Predicted Output: 0
# Input: [1 1] → Predicted Output: 1

# %% [markdown]
# Question 7: Implement and visualize Sigmoid, ReLU, and Tanh activation functions
# using Matplotlib.

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-10, 10, 1000)

def sigmoid(x):
    return 1 / (1 + np.exp(-x))

def relu(x):
    return np.maximum(0, x)

def tanh(x):
    return np.tanh(x)

y_sigmoid = sigmoid(x)
y_relu = relu(x)
y_tanh = tanh(x)

plt.figure(figsize=(10, 6))

plt.subplot(3, 1, 1)
plt.plot(x, y_sigmoid, 'r')
plt.title("Sigmoid Activation Function")
plt.ylabel("f(x)")
plt.grid(True)

plt.subplot(3, 1, 2)
plt.plot(x, y_relu, 'g')
plt.title("ReLU Activation Function")
plt.ylabel("f(x)")
plt.grid(True)

plt.subplot(3, 1, 3)
plt.plot(x, y_tanh, 'b')
plt.title("Tanh Activation Function")
plt.xlabel("Input (x)")
plt.ylabel("f(x)")
plt.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# Question 8: Use Keras to build and train a simple multilayer neural network on the
# MNIST digits dataset. Print the training accuracy.

# %%
import tensorflow as tf
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.utils import to_categorical

(x_train, y_train), (x_test, y_test) = mnist.load_data()

x_train = x_train / 255.0
x_test = x_test / 255.0

y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

model = Sequential([
    Flatten(input_shape=(28, 28)),
    Dense(128, activation='relu'),
    Dense(10, activation='softmax')
])

model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

history = model.fit(x_train, y_train, epochs=5, batch_size=32, verbose=1)

train_accuracy = history.history['accuracy'][-1]
print(f"\n✅ Training Accuracy: {train_accuracy * 100:.2f}%")
# Out:
# ...
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 15s 7ms/step - accuracy: 0.8763 - loss: 0.4359
# Epoch 2/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.9627 - loss: 0.1234
# Epoch 3/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9784 - loss: 0.0743
# Epoch 4/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9839 - loss: 0.0548
# Epoch 5/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9867 - loss: 0.0430
#
# ✅ Training Accuracy: 98.62%

# %% [markdown]
# Question 9: Visualize the loss and accuracy curves for a neural network model trained
# on the Fashion MNIST dataset. Interpret the training behavior.

# %%
import tensorflow as tf
from tensorflow.keras.datasets import fashion_mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.utils import to_categorical
import matplotlib.pyplot as plt

(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()

x_train = x_train / 255.0
x_test = x_test / 255.0

y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

model = Sequential([
    Flatten(input_shape=(28, 28)),
    Dense(128, activation='relu'),
    Dense(10, activation='softmax')
])

model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

history = model.fit(x_train, y_train,
                    validation_data=(x_test, y_test),
                    epochs=10,
                    batch_size=32,
                    verbose=1)

plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Training Accuracy', marker='o')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy', marker='o')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Training Loss', marker='o')
plt.plot(history.history['val_loss'], label='Validation Loss', marker='o')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()
# Out:
# ...
# 29515/29515 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# ...
# 26421880/26421880 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# ...
# 5148/5148 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# ...
# 4422102/4422102 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Epoch 1/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.7840 - loss: 0.6168 - val_accuracy: 0.8456 - val_loss: 0.4329
# Epoch 2/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.8633 - loss: 0.3750 - val_accuracy: 0.8611 - val_loss: 0.3885
# Epoch 3/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.8790 - loss: 0.3280 - val_accuracy: 0.8705 - val_loss: 0.3591
# Epoch 4/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.8868 - loss: 0.3095 - val_accuracy: 0.8685 - val_loss: 0.3745
# Epoch 5/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.8923 - loss: 0.2927 - val_accuracy: 0.8680 - val_loss: 0.3651
# Epoch 6/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.8947 - loss: 0.2814 - val_accuracy: 0.8790 - val_loss: 0.3432
# ...
